# %%
import tensorflow as tf
import numpy as np
from textloader import TextLoader
from tensorflow.python.ops.rnn_cell import BasicLSTMCell

# %%
def comp_graph(batch_sz, R = False, name = "First"):
    with tf.variable_scope("computation_graphs"):
        cell0 = BasicLSTMCell( state_dim )
        cell1 = BasicLSTMCell( state_dim )
        multi_cell = tf.contrib.rnn.MultiRNNCell([cell0, cell1])

        initial_state = multi_cell.zero_state(batch_sz, tf.float32)
        seq_out, final_state = tf.contrib.legacy_seq2seq.rnn_decoder(in_ph, initial_state, multi_cell)
        initializer = tf.contrib.layers.variance_scaling_initializer()
        logits  = [tf.layers.dense(seq_out[i], vocab_size, reuse = R) for i in xrange(sequence_length)]

        weights = [1.0 for _ in xrange(sequence_length)]
        seq_loss =  tf.contrib.legacy_seq2seq.sequence_loss(logits, targ_ph, weights)
        cell_train = tf.train.AdamOptimizer(learning_rate = c).minimize(seq_loss)

# %%
import tensorflow as tf
import numpy as np
from textloader import TextLoader


#
# -------------------------------------------
#
# Global variables

batch_size = 5
sample_batch = 1
sequence_length = 50
sample_seq = 1

data_loader = TextLoader( ".", batch_size, sequence_length )

vocab_size = data_loader.vocab_size  # dimension of one-hot encodings
state_dim = 128

num_layers = 2
c = .0001

tf.reset_default_graph()

#
# ==================================================================
# ==================================================================
# ==================================================================
#

# define placeholders for our inputs.  
# in_ph is assumed to be [batch_size,sequence_length]
# targ_ph is assumed to be [batch_size,sequence_length]

in_ph = tf.placeholder( tf.int32, [ batch_size, sequence_length ], name='inputs' )
targ_ph = tf.placeholder( tf.int32, [ batch_size, sequence_length ], name='targets' )
in_onehot = tf.one_hot( in_ph, vocab_size, name="s_input_onehot" )

inputs = tf.split( in_onehot, sequence_length, axis=1 )
inputs = [ tf.squeeze(input_, [1]) for input_ in inputs ]
targets = tf.split( targ_ph, sequence_length, axis=1 )

s_in_ph = tf.placeholder( tf.int32, [ 1 ], name='s_inputs' )
s_in_onehot = tf.one_hot( s_in_ph, vocab_size, name="s_input_onehot" )
s_inputs = tf.split( s_in_onehot, sample_seq, axis=0 )


# at this point, inputs is a list of length sequence_length
# each element of inputs is [batch_size,vocab_size]

# targets is a list of length sequence_length
# each element of targets is a 1D vector of length batch_size

# ------------------
# YOUR COMPUTATION GRAPH HERE

#comp_graph(batch_size)
R = False
with tf.name_scope("computation_graph"):
    cell0 = BasicLSTMCell( state_dim )
    cell1 = BasicLSTMCell( state_dim )
    multi_cell = tf.contrib.rnn.MultiRNNCell([cell0, cell1])

    initial_state = multi_cell.zero_state(batch_size, tf.float32)
    seq_out, final_state = tf.contrib.legacy_seq2seq.rnn_decoder(inputs, initial_state, multi_cell)
    initializer = tf.contrib.layers.variance_scaling_initializer()
    logits = []
    for i in xrange(sequence_length):
        logits.append(tf.layers.dense(seq_out[i], vocab_size, reuse = R))
        R = True
    
    weights = [1.0 for _ in xrange(sequence_length)]
    loss =  tf.contrib.legacy_seq2seq.sequence_loss(logits, targets, weights)
    optim = tf.train.AdamOptimizer(learning_rate = c).minimize(loss)


# ------------------
# YOUR SAMPLER GRAPH HERE

#comp_graph(sample_batch, R = True)
R = True
with tf.name_scope("sampler_graph"):
    s_initial_state = multi_cell.zero_state(sample_batch, tf.float32)
    s_seq_out, final_state = tf.contrib.legacy_seq2seq.rnn_decoder(s_inputs, s_initial_state, multi_cell)
    s_initializer = tf.contrib.layers.variance_scaling_initializer()
    s_logits  = [tf.layers.dense(seq_out[i], vocab_size, reuse = R) for i in xrange(sequence_length)]

    #s_weights = [1.0 for _ in xrange(sequence_length)]





#
# ==================================================================
# ==================================================================
# ==================================================================
#

def sample( num=200, prime='ab' ):

    # prime the pump

    # generate an initial state. this will be a list of states, one for
    # each layer in the multicell.
    s_state = sess.run( s_initial_state )

    # for each character, feed it into the sampler graph and
    # update the state.
    for char in prime[:-1]:
        x = np.ravel( data_loader.vocab[char] ).astype('int32')
        feed = { s_in_ph:x }
        for i, s in enumerate( s_initial_state ):
            feed[s] = s_state[i]
        s_state = sess.run( s_final_state, feed_dict=feed )

    # now we have a primed state vector; we need to start sampling.
    ret = prime
    char = prime[-1]
    for n in range(num):
        x = np.ravel( data_loader.vocab[char] ).astype('int32')

        # plug the most recent character in...
        feed = { s_in_ph:x }
        for i, s in enumerate( s_initial_state ):
            feed[s] = s_state[i]
        ops = [s_probs]
        ops.extend( list(s_final_state) )

        retval = sess.run( ops, feed_dict=feed )

        s_probsv = retval[0]
        s_state = retval[1:]
                # ...and get a vector of probabilities out!

        # now sample (or pick the argmax)
        # sample = np.argmax( s_probsv[0] )
        sample = np.random.choice( vocab_size, p=s_probsv[0] )

        pred = data_loader.chars[sample]
        ret += pred
        char = pred

    return ret

#
# ==================================================================
# ==================================================================
# ==================================================================
#

sess = tf.Session()
sess.run( tf.global_variables_initializer() )
summary_writer = tf.summary.FileWriter( "./tf_logs", graph=sess.graph )

lts = []

print "FOUND %d BATCHES" % data_loader.num_batches

for j in range(1000):

    state = sess.run( initial_state )
    data_loader.reset_batch_pointer()

    for i in range( data_loader.num_batches ):

        x,y = data_loader.next_batch()

        # we have to feed in the individual states of the MultiRNN cell
        feed = { in_ph: x, targ_ph: y }
        for k, s in enumerate( initial_state ):
            feed[s] = state[k]

        ops = [optim,loss]
        ops.extend( list(final_state) )
                # retval will have at least 3 entries:
        # 0 is None (triggered by the optim op)
        # 1 is the loss
        # 2+ are the new final states of the MultiRNN cell
        retval = sess.run( ops, feed_dict=feed )

        lt = retval[1]
        state = retval[2:]

        if i%1000==0:
            print "%d %d\t%.4f" % ( j, i, lt )
            lts.append( lt )

    print sample( num=60, prime="ab" )
#    print sample( num=60, prime="ababab" )
#    print sample( num=60, prime="foo ba" )
#    print sample( num=60, prime="abcdab" )

summary_writer.close()

#
# ==================================================================
# ==================================================================
# ==================================================================
#

#import matplotlib
#import matplotlib.pyplot as plt
#plt.plot( lts )
#plt.show()
# Out:
# loading preprocessed files
# FOUND 2 BATCHES
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-52-1ce8306ad21d> in <module>()
#     180         # 1 is the loss
#     181         # 2+ are the new final states of the MultiRNN cell
# --> 182         retval = sess.run( ops, feed_dict=feed )
#     183
#     184         lt = retval[1]
#
# /Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 's_inputs' with dtype int32 and shape [1]
# 	 [[Node: s_inputs = Placeholder[dtype=DT_INT32, shape=[1], _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# Caused by op u's_inputs', defined at:
#   File "/Users/catmcqueen/anaconda/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-52-1ce8306ad21d>", line 45, in <module>
#     s_in_ph = tf.placeholder( tf.int32, [ 1 ], name='s_inputs' )
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/ops/array_ops.py", line 1548, in placeholder
#     return gen_array_ops._placeholder(dtype=dtype, shape=shape, name=name)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 2094, in _placeholder
#     name=name)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2630, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/catmcqueen/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1204, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): You must feed a value for placeholder tensor 's_inputs' with dtype int32 and shape [1]
# 	 [[Node: s_inputs = Placeholder[dtype=DT_INT32, shape=[1], _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
